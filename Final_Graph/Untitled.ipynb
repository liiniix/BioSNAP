# %%
import pandas as pd

# %%
# !ls
# Out:
# disease_disease.csv  drug_drug.csv	    gene_function.csv
# disease_gene.csv     drug_gene.csv	    gene_gene.csv
# drug_disease.csv     function_tunction.csv  Untitled.ipynb

# %%
dis_dis = pd.read_csv("disease_disease.csv")
dr_dr = pd.read_csv("drug_drug.csv")
gene_func = pd.read_csv("gene_function.csv")
dis_gene = pd.read_csv("disease_gene.csv")
dr_gene = pd.read_csv("drug_gene.csv")
dr_dis = pd.read_csv("drug_disease.csv")
func_func = pd.read_csv("function_tunction.csv")

# %% [markdown]
# ## Dis-Dr and Dis-Gene

# %%
dr_dis
# Out:
#              Disease     Drug
# 0       MESH:D005923  DB00564
# 1       MESH:D009503  DB01072
# 2       MESH:D016115  DB01759
# 3       MESH:D018476  DB00451
# 4       MESH:C567059  DB00641
# 5       MESH:D010198  DB00481
# 6       MESH:D007898  DB04173
# 7       MESH:C574275  DB00636
# 8       MESH:D001249  DB00814
# 9       MESH:C535836  DB00091
# 10      MESH:D020149  DB01656
# 11      MESH:D009325  DB00851
# 12      MESH:D001943  DB00300
# 13      MESH:D006943  DB00749
# 14      MESH:D013612  DB01378
# 15      MESH:D014517  DB01164
# 16      MESH:D001281  DB01394
# 17      MESH:C537758  DB01093
# 18      MESH:D010391  DB00515
# 19      MESH:D002538  DB00727
# 20      MESH:D058489  DB04513
# 21      MESH:D012770  DB01235
# 22      MESH:D009205  DB00170
# 23      MESH:D018500  DB01174
# 24      MESH:D009374  DB01042
# 25      MESH:C567064  DB00396
# 26      MESH:D007805  DB00763
# 27      MESH:D006332  DB00820
# 28      MESH:D007035  DB00312
# 29      MESH:D009389  DB00722
# ...

# %%
dis_gene
# Out:
#                Disease       Gene
# 0         MESH:D005756      23262
# 1         MESH:D020293      23262
# 2         MESH:D062787      23262
# 3         MESH:D007859      23262
# 4         MESH:D019957      23262
# 5         MESH:D004065      23262
# 6         MESH:D020773      23262
# 7         MESH:D020031      23262
# 8         MESH:D018487      23262
# 9         MESH:D018567      23262
# 10        MESH:D000741      23262
# 11        MESH:D006461      23262
# 12        MESH:D006937      23262
# 13        MESH:D013086      23262
# 14        MESH:D013163      23262
# 15        MESH:D007022      23262
# 16        MESH:D001201      23262
# 17        MESH:D019964      23262
# 18        MESH:D020258      23262
# 19        MESH:D012509      23262
# 20        MESH:D003231      23262
# 21        MESH:D011297      23262
# 22        MESH:D006970      23262
# 23        MESH:D008569      23262
# 24        MESH:D002312      23262
# 25        MESH:D014657      23262
# ...

# %%
pd.merge(dr_dis, dis_gene, on="Disease")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-3769d29dbe79> in <module>
# ----> 1 pd.merge(dr_dis, dis_gene, on="Disease")
#
# /usr/lib/python3/dist-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      33                          right_index=right_index, sort=sort, suffixes=suffixes,
#      34                          copy=copy, indicator=indicator)
# ---> 35     return op.get_result()
#      36 if __debug__:
#      37     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# /usr/lib/python3/dist-packages/pandas/tools/merge.py in get_result(self)
#     194             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     195
# --> 196         join_index, left_indexer, right_indexer = self._get_join_info()
#     197
# ...
