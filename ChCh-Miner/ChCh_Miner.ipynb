# %%
import pandas as pd

# %%
# !ls
# Out:
# ChCh-Miner_durgbank-chem-chem.tsv     Untitled.ipynb
# ChCh-Miner_durgbank-chem-chem.tsv.gz

# %%
chch_miner = pd.read_csv("ChCh-Miner_durgbank-chem-chem.tsv", sep='\t')

# %%
chch_miner
# Out:
#          Drug1    Drug2
# 0      DB00862  DB00966
# 1      DB00575  DB00806
# 2      DB01242  DB08893
# 3      DB01151  DB08883
# 4      DB01235  DB01275
# 5      DB00018  DB00333
# 6      DB00201  DB01609
# 7      DB00712  DB01418
# 8      DB01576  DB04842
# 9      DB01609  DB06212
# 10     DB01232  DB09291
# 11     DB00382  DB06153
# 12     DB01017  DB01142
# 13     DB00214  DB01174
# 14     DB00104  DB00908
# 15     DB00569  DB01109
# 16     DB01222  DB09063
# 17     DB00898  DB01589
# 18     DB00762  DB09054
# 19     DB00780  DB01158
# 20     DB00186  DB09071
# 21     DB01248  DB06688
# 22     DB00484  DB00881
# 23     DB00396  DB00682
# 24     DB00368  DB01551
# 25     DB00054  DB00605
# 26     DB01320  DB09061
# 27     DB01167  DB01320
# 28     DB00186  DB00572
# 29     DB00921  DB09272
# ...        ...      ...
# 48484  DB01054  DB06724
# 48485  DB00798  DB00861
# 48486  DB01120  DB01380
# 48487  DB01192  DB09117
# 48488  DB01224  DB01253
# 48489  DB00333  DB01232
# ...

# %%
chch_miner.to_csv("drug_drug.csv", index=False)
