# %%
import pandas as pd

# %%
# !ls
# Out:
# CTD_genes_diseases.csv	   DG-Miner_miner-disease-gene.tsv     Untitled.ipynb
# CTD_genes_diseases.csv.gz  DG-Miner_miner-disease-gene.tsv.gz

# %%
ctd = pd.read_csv('DG-Miner_miner-disease-gene.tsv', sep='\t')

# %%
gene_list = ctd["Gene"].unique().tolist()

# %%
import urllib.parse
import urllib.request
import json

url = 'https://www.uniprot.org/uploadlists/'

# %%
string = gene_list[0]
for i, j in enumerate(gene_list):
    if i!=0:
        string = string +' '+ j

# %%
params = {
'from': 'ACC+ID',
'to': 'P_ENTREZGENEID',
'format': 'tab',
'query': string
}

data = urllib.parse.urlencode(params)
data = data.encode('utf-8')
req = urllib.request.Request(url, data)
with urllib.request.urlopen(req) as f:
   response = f.read()
print(response.decode('utf-8'))

f = open("urlprot_to_ncbi.tsv", "w")
f.write(response.decode('utf-8'))
f.close()
# Out:
# From	To

# %%
string
# Out:
# 'A0A087WZV0 P11464 Q92945 Q6ISS4 Q96RU8 O94986 Q6P1J9 J3KSP0 A0A087WYZ4 Q9UKN8 A0A087WXW9 Q92696 P22033 A0A087WWT6 A0A087WT39 Q8N6K0 O95628 O60832 A0A087WV34 E9PD53 Q14116 A6PW57 P05091 O43164 Q9UBR5 P36639 O95243 Q14832 P55072 Q9UL25 Q9BW71 O43768 O75323 O60603 P32004 H3BN99 Q9H307 Q8TF05 Q6NUJ5 Q8WY91 P54646 Q9NRX2 P07451 P67936 J3KN16 Q13257 P78348 H0Y4Z8 Q15059 Q02410 A0A087WZ70 A0A0A0MRL7 A0A0A6YYA8 P68371 P53602 Q16576 P35251 O75449 P26196 Q96EY8 Q96KN1 Q9Y248 P11169 Q8N1Q1 O15399 B1AN62 A0A0D9SFD0 P22760 Q96JF0 P56746 P05129 P33151 O75891 Q05639 Q9BWW7 O60291 Q9UPG8 Q99436 H3BNP7 Q9C0B2 Q16828 Q13296 Q9P107 Q6ZSS7 Q96A05 Q8NEB5 Q9Y2E6 Q8WXK3 Q5T6Z8 Q14571 Q92738 Q9NYS7 P40425 Q96HE9 Q5XKP0 P14555 P27707 Q86VW0 Q96PV7 H3BLT4 Q9NSE4 P13647 O60542 Q96JA1 P50221 P38117 Q13795 P16519 Q9UPE1 Q96HL8 Q96AE7 Q96GQ7 Q9P0W2 O43174 P05496 Q86U90 C9J6P4 A0A087WZX9 Q6BAA4 Q04900 Q9Y6J6 H3BMC5 A6NIX2 Q8WX93 P98164 Q8TC92 Q9H2D1 Q8TBB1 Q71F56 Q96MA6 Q8IYT3 P09972 P08263 E9PPN1