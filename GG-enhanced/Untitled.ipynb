# %%
import pandas as pd

# %%
# !ls HeteWalk
# Out:
# 1_BINARY_PROTEIN_PROTEIN_INTERACTIONS.txt  1.csv  2.csv  symbol_to_entrez.csv

# %%
ppi = pd.read_csv("HeteWalk/1_BINARY_PROTEIN_PROTEIN_INTERACTIONS.txt", sep='\t')

# %%
#xli = pd.concat([ppi['Interactor 1 Gene symbol'], ppi['Interactor 2 Gene symbol']], axis=0).unique().tolist()

# %%
ppi.head()
# Out:
#   Interactor 1 Gene symbol  Interactor 1 HPRD id Interactor 1 RefSeq id  \
# 0                  ALDH1A1                     1            NP_000680.2
# 1                    ITGA7                  2761         NP_001138468.1
# 2                  PPP1R9A                 16000            NP_060120.2
# 3                     SRGN                  1513            NP_002718.2
# 4                     GRB7                  3311            NP_005301.2
#
#   Interactor 2 Gene symbol  Interactor 2 HPRD id Interactor 2 RefSeq id  \
# 0                  ALDH1A1                     1            NP_000680.2
# 1                   CHRNA1                     7         NP_001034612.1
# 2                    ACTG1                    17            NP_001605.1
# 3                     CD44                   115            NP_000601.3
# 4                    ERBB2                  1281            NP_004439.2
#
#   Experiment type (in vivo, in vitro and yeast 2-hybrid)          Pubmed id
# ...

# %%
one =pd.read_csv("HeteWalk/1.csv")

# %%
one.head()
# Out:
#     SYMBOL  ENTREZID
# 0  ALDH1A1       216
# 1    ITGA7      3679
# 2  PPP1R9A     55607
# 3     SRGN      5552
# 4     GRB7      2886

# %%
two = pd.read_csv("HeteWalk/2.csv")

# %%
one
# Out:
#         SYMBOL  ENTREZID
# 0      ALDH1A1       216
# 1        ITGA7      3679
# 2      PPP1R9A     55607
# 3         SRGN      5552
# 4         GRB7      2886
# 5         PAK1      5058
# 6         DLG4      1742
# 7       PIK3R2      5296
# 8       PTPN18     26469
# 9      ERBB2IP       NaN
# 10      SMURF2     64750
# 11         NF2      4771
# 12        CD82      3732
# 13      ERRFI1     54206
# 14        MMP7      4316
# 15        TOB1     10140
# 16        MUC4      4585
# 17       PICK1      9463
# 18      SMURF2     64750
# 19       DDX20     11218
# 20        TLE1      7088
# 21        TLE3      7090
# 22       HDAC1      3065
# 23       SMAD1      4086
# 24       KDM5B     10765
# 25         CD4       920
# 26      SMURF2     64750
# 27         CBL       867
# 28       PLCG1      5335
# 29        PRLR      5618
# ...        ...       ...
# 39223     SHC1      6464
# 39224   PLXNB1      5364
# 39225     BAG1       573
# 39226     GLMN     11146
# 39227   RANBP9     10048
# ...

# %%
two.dropna(inplace=True)

# %%
two
# Out:
#         SYMBOL  ENTREZID
# 0      ALDH1A1       216
# 1       CHRNA1      1134
# 2        ACTG1        71
# 3         CD44       960
# 4        ERBB2      2064
# 5        ERBB2      2064
# 6        ERBB2      2064
# 7        ERBB2      2064
# 8        ERBB2      2064
# 9        ERBB2      2064
# 10     ARHGAP5       394
# 11       ERBB2      2064
# 12       ERBB2      2064
# 13       ERBB2      2064
# 14        CD44       960
# 15       ERBB2      2064
# 16       ERBB2      2064
# 17       ERBB2      2064
# 18       TXNIP     10628
# 19        ETV3      2117
# 20       FOXG1      2290
# 21       FOXG1      2290
# 22       FOXG1      2290
# 23       FOXG1      2290
# 24       FOXG1      2290
# 25        CD44       960
# 26        DAB2      1601
# 27        VAV1      7409
# 28        VAV1      7409
# 29        VAV1      7409
# ...        ...       ...
# 39225      MET      4233
# 39226      MET      4233
# 39227      MET      4233
# 39228      MET      4233
# 39229      MET      4233
# ...

# %%
result = one.append(two)

# %%
result.drop_duplicates()
# Out:
#            SYMBOL  ENTREZID
# 0         ALDH1A1       216
# 1           ITGA7      3679
# 2         PPP1R9A     55607
# 3            SRGN      5552
# 4            GRB7      2886
# 5            PAK1      5058
# 6            DLG4      1742
# 7          PIK3R2      5296
# 8          PTPN18     26469
# 10         SMURF2     64750
# 11            NF2      4771
# 12           CD82      3732
# 13         ERRFI1     54206
# 14           MMP7      4316
# 15           TOB1     10140
# 16           MUC4      4585
# 17          PICK1      9463
# 19          DDX20     11218
# 20           TLE1      7088
# 21           TLE3      7090
# 22          HDAC1      3065
# 23          SMAD1      4086
# 24          KDM5B     10765
# 25            CD4       920
# 27            CBL       867
# 28          PLCG1      5335
# 29           PRLR      5618
# 30           TYK2      7297
# 32          MAPK1      5594
# 33           VAV1      7409
# ...           ...       ...
# 37565         MTR      4548
# ...

# %%
symbol_to_entrez = result

# %%
symbol_to_entrez.to_csv("symbol_to_entrez.csv", index=False)
